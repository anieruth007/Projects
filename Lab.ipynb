# %% [markdown]
# <a href="https://colab.research.google.com/github/anieruth007/Projects/blob/main/Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Anieruth.csv')
df
# Out:
#     Sl.No Course Code                                       Course Title  \
# 0       1     CHY1002                             Environmental Sciences
# 1       2     CSE1013               Problem Solving and programming in C
# 2       3     ENG1902                             Technical English - II
# 3       4     FRE1001                                 Francais quotidien
# 4       5     HUM1021                                  Ethics and Values
# 5       6     MAT5015                          Mathematics for Engineers
# 6       7     PHY1701                                Engineering Physics
# 7       8     STS1021                        Introduction to Soft Skills
# 8       9     CSE1018  Problem Solving and Object Oriented Programmin...
# 9      10     CSE1021            Digital Logic and Computer Organization
# 10     11     EEE1019  Foundations of Electrical and Electronics Engi...
# 11     12     MAT1021           Probability and Statistics for Engineers
# ...

# %%
df1=df['Grade']=='A'
df2=df.loc[df1,'Exam Month']
print(df2)
# Out:
# 0     Jan-2023
# 6     Jan-2023
# 18    Dec-2023
# 19    Dec-2023
# 20    Dec-2023
# 29    May-2024
# 30    May-2024
# Name: Exam Month, dtype: object

# %%
df3=df['Course Title'].count()
df3
# Out:
# 33

# %%
#most occurence of grade

df['Grade'].value_counts()
# Out:
# Grade
# B    16
# A     7
# C     5
# D     3
# N     1
# P     1
# Name: count, dtype: int64
